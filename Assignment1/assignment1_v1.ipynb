# %%
import nltk
import pandas as pd
import re

# %%
# reading the data
df = pd.read_csv('./a01_spam.csv')
print(df.size)
df.head()
# Out:
# 11144
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Task 1: Printing the number of words starting with consonants and the number of words starting with vowels in all the messages.

# %%
from nltk.tokenize import word_tokenize

# %%
messageList = df['Message'].tolist()
wordsStartingWithConsonents = 0
wordsStartingWithVowels = 0

# %%
missingVowel = set()
from nltk.tokenize import RegexpTokenizer
vowelTokenizer = RegexpTokenizer(r"\b[aeiouAEIOU][^\s]+|\b[aeiouAEIOU]\b")
consonantTokenizer = RegexpTokenizer(
    r"\b[^\W\daeiouAEIOU][^\s]+|\b[^\W\daeiouAEIOU]\b")
v = 0
c = 0
for i in messageList:
    # print(i)
    # print(vowelTokenizer.tokenize(i))
    # print(consonantTokenizer.tokenize(i))
    v += len(vowelTokenizer.tokenize(i))
    for word in vowelTokenizer.tokenize(i):
        if word not in vowelSet:
            missingVowel.add(word)
    c += len(consonantTokenizer.tokenize(i))
    # for word in consonantTokenizer.tokenize(i):
        # if word not in consonantSet:
        #     print(word)
print(v, c)
print(missingVowel)
# Out:
# 21483 62263
# ...

# %%
wordSet = set()
wordsStartingWithVowels = 0
wordsStartingWithConsonents = 0
for i in messageList:
    words = re.split("\s|(?<!\d)[,./!:?\(\)\[\]-](?!\d)", i)
    print(i)
    print(words)
    for word in words:
        if len(word) and word[0].lower() in 'aeiou':
            wordsStartingWithVowels += 1
            wordSet.add(word)
            vowelSet.add(word)
        elif len(word) and word[0].lower() in 'qwrtypsdfghjklzxcvbnm':
            wordsStartingWithConsonents += 1
            wordSet.add(word)
            consonantSet.add(word)
# Out:
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# ['Go', 'until', 'jurong', 'point', '', 'crazy', '', '', 'Available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '', '', '', 'Cine', 'there', 'got', 'amore', 'wat', '', '', '']
# Ok lar... Joking wif u oni...
# ['Ok', 'lar', '', '', '', 'Joking', 'wif', 'u', 'oni', '', '', '']
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# ['Free', 'entry', 'in', '2', 'a', 'wkly', 'comp', 'to', 'win', 'FA', 'Cup', 'final', 'tkts', '21st', 'May', '2005.', 'Text', 'FA', 'to', '87121', 'to', 'receive', 'entry', 'question', 'std', 'txt', 'rate', "T&C's", 'apply', "08452810075over18's"]
# U dun say so early hor... U c already then say...
# ['U', 'dun', 'say', 'so', 'early', 'hor', '', '', '', 'U', 'c', 'already', 'then', 'say', '', '', '']
# ...

# %%
print("Words starting with vowels: ", wordsStartingWithVowels)
print("Words starting with consonants: ", wordsStartingWithConsonents)
# Out:
# Words starting with vowels:  21369
# Words starting with consonants:  61726

# %%
s = "Aritish"
if len(s) and s[0].lower() in 'aeiou':
    print(s)
# Out:
# Aritish

# %% [markdown]
# # Task 2: Compute the percentage of capitalized words in spam and ham messages

# %%
spamSmall = 0
spamCap = 0
hamSmall = 0
hamCap = 0

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
spamSmall = 0
spamCap = 0
hamSmall = 0
hamCap = 0
for category, message in df.iterrows(): 
    if message['Category'] == 'spam':
        words = re.split("\s|(?<!\d)[,./!:?\(\)\[\]-](?!\d)", message['Message'])
        for word in words:
            if len(word) and word[0].isalpha() and word[0].islower():
                spamSmall += 1
            elif len(word) and word[0].isalpha() and word[0].isupper():
                spamCap += 1
    else:
        words = re.split("\s|(?<!\d)[,./!:?\(\)\[\]-](?!\d)", message['Message'])
        for word in words:
            if len(word) and word[0].isalpha() and word[0].islower():
                hamSmall += 1
            elif len(word) and word[0].isalpha() and word[0].isupper():
                hamCap += 1

# %%
print("Spam Small: ", spamSmall)
print("Spam Cap: ", spamCap)
print("Ham Small: ", hamSmall)
print("Ham Cap: ", hamCap)
# Out:
# Spam Small:  10550
# Spam Cap:  5335
# Ham Small:  54398
# Ham Cap:  12991

# %%
print("Percentage of capitalized words in Spam messages = " + str(((spamCap / (spamSmall + spamCap))*100)) + "%")
print("Percentage of capitalized words in Ham messages = " + str(((hamCap / (hamSmall + hamCap))*100)) + "%")
# Out:
# Percentage of capitalized words in Spam messages = 33.58514321687126%
# Percentage of capitalized words in Ham messages = 19.277626912404102%

# %%
consonantSet = set()
vowelSet = set()

# %% [markdown]
# # Task 3: List all email ids and phone/mobile numbers and their respective counts in the dataset. Compute the percentage for spam and ham messages for both email and mobile numbers.

# %%
emails = []
for i in messageList:
    emailList = re.findall(r"\S+@\S+", i)
    for email in emailList:
        emails.append(email)
for email in emails:
    print(email)
# Out:
# 31p.msg@150p
# yijue@hotmail.com
# recd@thirtyeight
# 31p.msg@150p
# MonthlySubscription@50p/msg
# XCLUSIVE@CLUBSAISAI
# Hello-/@drivby-:0quit
# info@ringtoneking.co.uk
# info@vipclub4u.
# tddnewsletter@emc1.co.uk
# info@txt82228.co.uk
# Nyt.EC2A.3LP.msg@150p
# msgs@150p
# chrgd@50p
# msgs@150p
# Dorothy@kiefer.com
# msg@£1.50rcvd
# msg+ticket@kiosk.Valid
# customersqueries@netvision.uk.com
# charged@150p/msg.2

# %%
numberOfSpam = 0
numberOfHam = 0
for category, message in df.iterrows():
    if message['Category'] == 'spam':
        numberOfSpam += 1
    else:
        numberOfHam += 1
print(numberOfSpam)
print(numberOfHam)
# Out:
# 747
# 4825

# %%
emailList = {}
emailInSpam = 0
emailInHam = 0
for category, message in df.iterrows():
    tempList = re.findall(
        r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[a-z]{2,}\b", message['Message'])
    if len(tempList)>0:
        if message['Category'] == 'spam':
            emailInSpam += 1
        else:
            emailInHam += 1
    for email in tempList:
        if email in emailList:
            emailList[email] += 1
        else:
            emailList[email] = 1
for email in emailList:
    print(email + ":" + str(emailList[email]))
print("Email in spam: " + str(emailInSpam))
print("Email in ham: " + str(emailInHam))
print("Percentage of Email in spam: " + str(emailInSpam*100/numberOfSpam) + "%")
print("Percentage of Email in ham: " + str(emailInHam*100/numberOfHam) + "%")
# Out:
# yijue@hotmail.com:1
# info@ringtoneking.co.uk:1
# tddnewsletter@emc1.co.uk:1
# info@txt82228.co.uk:1
# Dorothy@kiefer.com:1
# customersqueries@netvision.uk.com:1
# Email in spam: 5
# Email in ham: 1
# Percentage of Email in spam: 0.6693440428380187%
# Percentage of Email in ham: 0.02072538860103627%

# %%
numbersList = {}
numberInSpam = 0
numberInHam = 0
for category, message in df.iterrows():
    numberList = re.findall(r"\b[0]?\d{3}[\s-]?\d{3}[\s-]?\d{4}\b", message['Message'])
    for number in numberList:
        if number in numbersList:
            numbersList[number] += 1
        else:
            numbersList[number] = 1
    if len(numberList) > 0:
        if message['Category'] == 'spam':
            numberInSpam += 1
        else:
            numberInHam += 1
for number in numbersList:
    print(number + ":" + str(numbersList[number]))
print("Numbers in spam: " + str(numberInSpam))
print("Numbers in ham: " + str(numberInHam))
print("Percentage of Numbers in spam: " + str(numberInSpam*100/numberOfSpam) + "%")
print("Percentage of Numbers in ham: " + str(numberInHam*100/numberOfHam) + "%")
# Out:
# 09061701461:2
# 08002986030:2
# 07732584351:1
# 08000930705:16
# 09061209465:3
# 09066364589:2
# 0800 169 6031:2
# 09064012160:2
# 07742676969:2
# 08719180248:2
# 09064019788:1
# 08712300220:6
# 07046744435:1
# 09061701939:1
# 0808 145 4742:4
# 09058094597:2
# 0125698789:1
# 0845 021 3680:2
# 08002986906:4
# 08718720201:7
# 08708800282:1
# 08000839402:15
# 08717205546:1
# 09057039994:1
# 08000938767:3
# 0845 2814032:1
# 09064012103:1
# 07123456789:2
# 09111032124:1
# 09058094455:1
# 09066382422:2
# 0800 1956669:3
# 0207 153 9153:1
# 09061743806:2
# 07781482378:2
# 0871-872-9755:1
# 08717898035:3
# 07815296484:1
# 08718738001:2
# 09050005321:1
# 08002988890:1
# 08715705022:4
# 08712402050:2
# 07753741225:1
# 08715203677:1
# 0800 542 0825:2
# 07946746291:1
# 07880867867:1
# 09064019014:2
# 08715203694:1
# 08718711108:1
# 08452810071:1
# 08712404000:1
# 08714712388:1
# 08714712394:1
# 08706091795:2
# 09066368327:1
# 0800 542 0578:2
# 08718727870:4
# 0207 153 9996:1
# 08000407165:2
# ...

# %% [markdown]
# # Task 4: List all monetary quantities, e.g., £1000. Compute the percentage of spam and ham messages with monetary quantities

# %%
moneyList = []
spamWithMoney = 0
hamWithMoney = 0
for category, message in df.iterrows():
    j = message['Message'].replace(",", "")
    tempList = re.findall(
        r"(?:\$|\¥|\€|\¢|\£|\₹|Rs\.|rs\.)\s?\d+(?:\.\d+)?(?:(?:/|\sper\s)(?:min|hr|sec|pax|s|month|wk|msg|day|SMS|m|tone|Msg))?|\d+(?:\.\d+)?p/(?:min|hr|sec|pax|s|month|wk|msg|day|SMS|m|tone|Msg)?", j)
    if len(tempList)>0:
        print(j)
        print(tempList)
        if message['Category'] == 'spam':
            spamWithMoney += 1
        else:
            hamWithMoney += 1
    for money in tempList:
        moneyList.append(money)
    
print(spamWithMoney, hamWithMoney)
print("Percentage of Spam messages with monetory quantity = " + str(spamWithMoney*100/numberOfSpam) + "%")
print("Percentage of Ham messages with monetory quantity = " + str(hamWithMoney*100/numberOfHam) + "%")
# Out:
# FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send £1.50 to rcv
# ['£1.50']
# WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.
# ['£900']
# SIX chances to win CASH! From 100 to 20000 pounds txt> CSH11 and send to 87575. Cost 150p/day 6days 16+ TsandCs apply Reply HL 4 info
# ['150p/day']
# URGENT! You have won a 1 week FREE membership in our £100000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18
# ['£100000']
# Thanks for your subscription to Ringtone UK your mobile will be charged £5/month Please confirm by replying YES or NO. If you reply NO you will not be charged
# ['£5/month']
# Your gonna have to pick up a $1 burger for yourself on your way home. I can't even move. Pain is killing me.
# ['$1']
# ...

# %%
moneyList = []
for i in messageList:
    j = i.replace(",", "")
    tempList = re.findall(r"([\$\¥\€\¢\£\₹]\s?)\d+", j)
    if len(tempList) > 0:
        print(j)
    for money in tempList:
        print(money)
# Out:
# FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send £1.50 to rcv
# £
# WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.
# £
# URGENT! You have won a 1 week FREE membership in our £100000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18
# £
# Thanks for your subscription to Ringtone UK your mobile will be charged £5/month Please confirm by replying YES or NO. If you reply NO you will not be charged
# £
# Your gonna have to pick up a $1 burger for yourself on your way home. I can't even move. Pain is killing me.
# $
# As a valued customer I am pleased to advise you that following recent review of your Mob No. you are awarded with a £1500 Bonus Prize call 09066364589
# £
# ...

# %%
reg = "((\$|\¥|\€|\¢|\£|\₹|Rs\.|rs\.)\s?)\d+(\.\d+)?(/(min)|(hr)|(sec)|(pax)|(month))?|(\d+(\.\d+)?)p?/(min|sec|hr|pax|s)"
sent = "Rs. 4000.50 is best"
tempList = re.findall(
    r"(?:\$|\¥|\€|\¢|\£|\₹|Rs\.|rs\.)\s?\d+(?:\.\d+)?(?:(?:/|\sper\s)(?:min|hr|sec|pax|s|month))?|\d+(?:\.\d+)?p?(?:(?:/|\sper\s)(?:min|hr|sec|pax|s|month))?", sent)
print(tempList)
# Out:
# ['Rs. 4000.50']

# %%
sent = "india40 china40"
tempList = re.findall(r"(?:india|china){1}\d+", sent)
print(tempList)
# Out:
# ['india40', 'china40']

# %% [markdown]
# # Task 5:Count and print all emoticons in the dataset.

# %%
from nltk.tokenize.casual import TweetTokenizer

# %%
tt = TweetTokenizer()

# %%
sent = "My name is Pritish u:)"
print(tt.tokenize(sent))
# Out:
# ['My', 'name', 'is', 'Pritish', 'u', ':)']

# %%
numEmoticons = 0
emoticonSet = set()
for i in messageList:
    words = tt.tokenize(i)
    emotiList = []
    for word in words:
        if re.search(
            r"^\:\w+\:$|^<[\\\/]?3$|^[\)\(\$\*][-^=]?[:;=]$|^[:;=][-^=]?[\(\)Pp0Oo3D\|\\\/\$\*\@$]", word):
            numEmoticons += 1
            emoticonSet.add(word)
            emotiList.append(word)
    # if len(emotiList) > 0:
        # print(i)
        # print(emotiList)

for emoticon in emoticonSet:
    # if '8' in emoticon:
        print(emoticon)
print(numEmoticons)
print(len(emoticonSet))
# Out:
# ;)
# :)
# :/
# ;-(
# :-|
# :-D
# =D
# =/
# =)
# <3
# :-(
# :D
# :-P
# :-)
# ;-)
# :-/
# :(
# 441
# 17

# %% [markdown]
# # Task 6: Print a list of words with clitics

# %%
from nltk.tokenize import word_tokenize

for i in messageList:
    words = word_tokenize(i)
    print(words)
# Out:
# ['Go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'Available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'Cine', 'there', 'got', 'amore', 'wat', '...']
# ['Ok', 'lar', '...', 'Joking', 'wif', 'u', 'oni', '...']
# ['Free', 'entry', 'in', '2', 'a', 'wkly', 'comp', 'to', 'win', 'FA', 'Cup', 'final', 'tkts', '21st', 'May', '2005', '.', 'Text', 'FA', 'to', '87121', 'to', 'receive', 'entry', 'question', '(', 'std', 'txt', 'rate', ')', 'T', '&', 'C', "'s", 'apply', '08452810075over18', "'s"]
# ['U', 'dun', 'say', 'so', 'early', 'hor', '...', 'U', 'c', 'already', 'then', 'say', '...']
# ['Nah', 'I', 'do', "n't", 'think', 'he', 'goes', 'to', 'usf', ',', 'he', 'lives', 'around', 'here', 'though']
# ...

# %%
from nltk.tokenize import RegexpTokenizer

# %%
rt = RegexpTokenizer(r"\s|(?<!\d)[,./!:?\(\)\[\]-](?!\d)")
clitics = []
cliticSet = set()
numClitics = 0
for i in messageList:
    # words = rt.tokenize(i)
    # words2 = nltk.tokenize.wordpunct_tokenize(i)
    words = re.split("\s|(?<!\d)[,./!:?&\(\)\[\]-](?!\d)", i)
    # print(i)
    # print(words)
    # print(words2)
    # print(words3)
    # print(i)
    tempList = []
    for word in words:
        if re.search(r"[a-zA-Z\&]+\'[a-zA-Z]+", word):
            cliticSet.add(word)
            clitics.append(word)
            numClitics += 1
            tempList.append(word)
    if len(tempList) > 0:
        print(i)
        print(tempList)
print(numClitics)
print(len(cliticSet))
for clitic in cliticSet:
    print(clitic)
# Out:
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# ["C's"]
# Nah I don't think he goes to usf, he lives around here though
# ["don't"]
# FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv
# ["it's", "week's", "I'd"]
# I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.
# ["I'm", "don't", "I've"]
# I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.
# ["I've"]
# Oh k...i'm watching here:)
# ["i'm"]
# Just forced myself to eat a slice. I'm really not hungry tho. This sucks. Mark is getting worried. He knows I'm sick when I turn down pizza. Lol
# ["I'm", "I'm"]
# ...
